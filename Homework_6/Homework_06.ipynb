# %% [markdown]
# ## 1. Web Scraping
#
# Modify the scripts we used in class to make a program to download both tables present in the  wikipedia page on the Anscombe's Quartet (https://en.wikipedia.org/wiki/Anscombe%27s_quartet). Each table should be saved in its own csv file. **Note:** Your file for the first table should contain the column names, the file for the second table does not need the column names.

# %%
import requests
page = requests.get("https://en.wikipedia.org/wiki/Anscombe%27s_quartet")

data = page.text

from bs4 import BeautifulSoup
soup = BeautifulSoup(data,'html5lib')

import pandas as pd

for table in soup.find_all("table"):
    if table.find('caption'):
        fullTable = []
        for tr in table.find_all('tr'):
            line = []
            if tr.find_all('th'):
                columnNames = []
                for td in tr.find_all('th'):
                    columnNames.append(td.get_text().strip())
            else:
                for td in tr.find_all('td'):
                    line.append(td.get_text().strip())
                fullTable.append(line)

if len(columnNames) == len(fullTable[1]):
    newTable = pd.DataFrame(fullTable, columns = columnNames)
else:
    newTable = pd.DataFrame(fullTable)
newTable

for table in soup.find_all("table"):
    if table.find('Property'):
        fullTable = []
        for tr in table.find_all('tr'):
            line = []
            if tr.find_all('th'):
                columnNames = []
                for td in tr.find_all('th'):
                    columnNames.append(td.get_text().strip())
            else:
                for td in tr.find_all('td'):
                    line.append(td.get_text().strip())
                fullTable.append(line)

if len(columnNames) == len(fullTable[1]):
    newTable = pd.DataFrame(fullTable, columns = columnNames)
else:
    newTable = pd.DataFrame(fullTable)
newTable

newTable.to_csv('iris.csv')

# %% [markdown]
# ## 2. Pandas and Stats
#
# The Iris dataset is one of the most famous datasets in statistics. Read about it in wikipedia: https://en.wikipedia.org/wiki/Iris_flower_data_set.
#
# Download the dataset from the table in the wikipedia page using beatifulsoup, create a pandas dataframe containing the dataset (including column names). **Note: ** The first column of the table contains only the order of the points in the dataset, it should become the index of your data frame.

# %%
import pandas as pd
import plotly.graph_objs as go
import plotly.express as pxg
import numpy as np
from matplotlib import pyplot as plt
import requests
page = requests.get("https://en.wikipedia.org/wiki/Iris_flower_data_set")

data = page.text

from bs4 import BeautifulSoup
soup = BeautifulSoup(data,'html5lib')

import pandas as pd

for table in soup.find_all("table"):
    if table.find('caption'):
        fullTable = []
        for tr in table.find_all('tr'):
            line = []
            if tr.find_all('th'):
                columnNames = []
                for td in tr.find_all('th'):
                    columnNames.append(td.get_text().strip())
            else:
                for td in tr.find_all('td'):
                    line.append(td.get_text().strip())
                fullTable.append(line)

if len(columnNames) == len(fullTable[1]):
    newTable = pd.DataFrame(fullTable, columns = columnNames)
else:
    newTable = pd.DataFrame(fullTable)
newTable
newTable.to_csv('iris.csv')

data = pd.read_csv('iris.csv')

# %% [markdown]
# Your dataframe now should have string values in the columns, you need to convert each of the columns that should contain numbers to numeric values (Check the function `pd.to_numeric`).
#
# After converting the columns to numeric use the `desribe()` method to  calculate the average and standard deviation for each variable.

# %%
pd.to_numeric(data['Sepal length'])
pd.to_numeric(data['Sepal width'])
pd.to_numeric(data['Petal length'])
pd.to_numeric(data['Petal width'])

data.describe()
# Out:
#        Dataset order  Sepal length  Sepal width  Petal length  Petal width
# count     150.000000    150.000000   150.000000    150.000000   150.000000
# mean       75.500000      5.843333     3.057333      3.758000     1.200000
# std        43.445368      0.828066     0.435866      1.765298     0.761401
# min         1.000000      4.300000     2.000000      1.000000     0.100000
# 25%        38.250000      5.100000     2.800000      1.600000     0.300000
# 50%        75.500000      5.800000     3.000000      4.350000     1.300000
# 75%       112.750000      6.400000     3.300000      5.100000     1.800000
# max       150.000000      7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Use the `.groupby()` method to group the data by species and calculate the average and standard deviation for each variable based on the iris species.

# %%
SpeciesAvg = data.groupby(['Species']).mean()
SpeciesStd = data.groupby(['Species']).std()

print(SpeciesAvg)
print(SpeciesStd)
# Out:
#                Dataset order  Sepal length  Sepal width  Petal length  \
# Species
# I. setosa               25.5         5.006        3.428         1.462
# I. versicolor           75.5         5.936        2.770         4.260
# I. virginica           125.5         6.588        2.974         5.552
#
#                Petal width
# Species
# I. setosa            0.248
# I. versicolor        1.326
# I. virginica         2.026
#                Dataset order  Sepal length  Sepal width  Petal length  \
# Species
# I. setosa           14.57738      0.352490     0.379064      0.173664
# I. versicolor       14.57738      0.516171     0.313798      0.469911
# I. virginica        14.57738      0.635880     0.322497      0.551895
#
#                Petal width
# Species
# I. setosa         0.105444
# I. versicolor     0.197753
# I. virginica      0.274650

# %% [markdown]
# Make scatter plot showing the covariance of the variables. Check plotly's `create_scatterplotmatrix` function from the `figure_factory`. Your graph should look like this:
#
# <img src="iris.png"></img>

# %%
import plotly
import plotly.graph_objs as go
import plotly.express as pxg
from plotly.offline import iplot
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as ff

import numpy as np
import pandas as pd

fig = ff.create_scatterplotmatrix(data, diag='histogram', index='Species',
                                  height=800, width=800)
fig.update_layout(
    title={
        'text': "Iris Scatterplot Matrix",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
iplot(fig, filename='Histograms along Diagonal Subplots')
